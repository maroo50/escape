# %% [markdown]
# # 앤스콤 데이터 집합 불러오기

# %%
import seaborn as sns

anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# # matplotlib 라이브러리로 간단한 그래프 그리기

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset']=='I']

# %%
plt.plot(dataset_1['x'],dataset_1['y'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %% [markdown]
# # 한 번에 4개의 그래프 그리기

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# %%
axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

# %%
axes1.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")
# Out:
# Text(0.5, 1.0, 'dataset_4')

# %%
fig.suptitle("Anscombe Data")
fig
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig.tight_layout() # 겹친부분을 조절하여 그래프 레이아웃을 조절
fig
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %% [markdown]
# # 기초 그래프 그리기 - 히스토그램, 산점도, 박스 그래프

# %%
## tips 데이터프레임은 지불금액, 팁, 성별, 흡연유무, 요일, 시간, 전체 인원정보를 담고 있음

# %%
tips = sns.load_dataset("tips")
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(1, 1, 1)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
axes1.hist(tips['total_bill'], bins=10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

fig
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
# 산점도 그래프 == 이변량 그래프

scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)

axes1.scatter(tips['total_bill'], tips['tip'])   ## 이부분 오타냈네..
axes1.set_title('Scatterplot of Total Bill vs Tip') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# Text(0, 0.5, 'Tip')

# %%
# 박스 그래프 이산형 변수와 연속형 변수를 함께 사용하는 그래프
# 이산형변수 : Female, Male 과 같이 명확하게 구분되는 값을 의미
# 연속형변수  : tip과 같이 명확하게 셀수 없는 볌위의 값을 의미

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot([tips[tips['sex']=='Female']['tip'],  tips[tips['sex'] == 'Male']['tip']], labels = ['Female', 'Male'])

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# # 단변량 그래프 그리기 - 히스토그램

# %%
def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)

axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size'] * 10,  # s 는 점 크기 (size)
    c=tips['sex_color'],  # c 는  인잣값을 0.5로 지정하여 점의 투명도를 보기 좋게함
    alpha=0.5)

axes1.set_title('Total Bill vs Tip Colored by sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# Text(0, 0.5, 'Tip')

# %% [markdown]
# # 다변량 그래프 그리기

# %% [markdown]
# # 데이터프레임과 시리즈로 그래프 그리기

# %% [markdown]
# # 알아두면 좋아요
