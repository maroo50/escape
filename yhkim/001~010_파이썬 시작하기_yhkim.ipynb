# %%
# Print 관련 함수
print("Hello World")
print("Mary's cosmetics") # '로 인한 큰따옴표 사용
# Out:
# Hello World
# Mary's cosmetics

# %% [markdown]
# ## 011 변수 사용하기
# #### 삼성전자라는 변수로 50,000원을 바인딩해보세요. 삼성전자 주식 10주를 보유하고 있을 때 총 평가금액을 출력하세요.

# %% [markdown]
# ## 001 ~ 010  시작하기

# %%
print("hello Wolrd")
print("Mary\'s cosmetics")
print("Mary's cosmetics") #정답
print("신씨가 소리질렀다. \"도둑이야\"")
print('신씨가 소리질렀다. "도둑이야"') #정답
print('"C:\\Windows"')
print("안녕하세요.\n만나서\t\t반갑습니다.")
print("오늘은", "일요일")
print("naver","kakao", "sk", "samsumg", sep=';')
print("naver","kakao", "sk", "samsumg", sep='/')
print("first", end=""); print("second")
print(5/3)
# Out:
# hello Wolrd
# Mary's cosmetics
# Mary's cosmetics
# 신씨가 소리질렀다. "도둑이야"
# 신씨가 소리질렀다. "도둑이야"
# "C:\Windows"
# 안녕하세요.
# 만나서		반갑습니다.
# 오늘은 일요일
# naver;kakao;sk;samsumg
# naver/kakao/sk/samsumg
# firstsecond
# 1.6666666666666667

# %% [markdown]
# ## 011~012 변수 사용하기
# ##### 다음 표는 삼성전자의 일부 투자정보입니다. 변수를 사용해서 시가총액, 현재가, PER 등을 바인딩해보세요.
#
# 항목	값
# 시가총액	298조
# 현재가	50,000원
# PER	15.79

# %%
삼성전자=50000
보유=10
총평가금액=삼성전자*보유
print("총평가금액 = ", 총평가금액)

시가총액 = 298000000000000
현재가 = 5000
PER = 15.79
print(시가총액, type(시가총액))
print(현재가, type(현재가))
print(PER, type(PER))
# Out:
# 총평가금액 =  500000
# 298000000000000 <class 'int'>
# 5000 <class 'int'>
# 15.79 <class 'float'>

# %%
print('신씨가 소리질렀다. "도둑이야".') # ""로 인한 작은따옴표 사용
# Out:
# 신씨가 소리질렀다. "도둑이야".

# %%
print("C:\Windows")
# Out:
# C:\Windows

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.") # \n은 줄바꿈 / \t는 탭
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
print ("오늘은", "일요일") # 여러값을 출력할 때 쉼표로 구분
# Out:
# 오늘은 일요일

# %%
print("naver","kakao","sk","samsung", sep= ";") #sep 인자로 ";"를 입력하면 출력되는 값이 한칸 공백 대신 세미콜론 출력
# Out:
# naver;kakao;sk;samsung

# %%
print("naver","kakao","sk","samsung", sep= "/")
# Out:
# naver/kakao/sk/samsung

# %%
#줄바꿈없이 다음 코드를 출력(힌트: end='') print 함수는 두 번 사용합니다.세미콜론 (;)은 한줄에 여러 개의 명령을 작성하기 위해 사용합니다.
print("first", end= "");print("second")
# Out:
# firstsecond

# %%
print(5/3)
# Out:
# 1.6666666666666667
