# %%
# Print 관련 함수
print("Hello World")
print("Mary's cosmetics") # '로 인한 큰따옴표 사용
# Out:
# Hello World
# Mary's cosmetics

# %% [markdown]
# ## 011 변수 사용하기
# #### 삼성전자라는 변수로 50,000원을 바인딩해보세요. 삼성전자 주식 10주를 보유하고 있을 때 총 평가금액을 출력하세요.

# %% [markdown]
# ## 001 ~ 010  시작하기

# %%
print("hello Wolrd")
print("Mary\'s cosmetics")
print("Mary's cosmetics") #정답
print("신씨가 소리질렀다. \"도둑이야\"")
print('신씨가 소리질렀다. "도둑이야"') #정답
print('"C:\\Windows"')
print("안녕하세요.\n만나서\t\t반갑습니다.")
print("오늘은", "일요일")
print("naver","kakao", "sk", "samsumg", sep=';')
print("naver","kakao", "sk", "samsumg", sep='/')
print("first", end=""); print("second")
print(5/3)
# Out:
# hello Wolrd
# Mary's cosmetics
# Mary's cosmetics
# 신씨가 소리질렀다. "도둑이야"
# 신씨가 소리질렀다. "도둑이야"
# "C:\Windows"
# 안녕하세요.
# 만나서		반갑습니다.
# 오늘은 일요일
# naver;kakao;sk;samsumg
# naver/kakao/sk/samsumg
# firstsecond
# 1.6666666666666667

# %% [markdown]
# ## 011~012 변수 사용하기
# ##### 다음 표는 삼성전자의 일부 투자정보입니다. 변수를 사용해서 시가총액, 현재가, PER 등을 바인딩해보세요.
#
# 항목	값
# 시가총액	298조
# 현재가	50,000원
# PER	15.79

# %%
삼성전자=50000
보유=10
총평가금액=삼성전자*보유
print("총평가금액 = ", 총평가금액)

시가총액 = 298000000000000
현재가 = 5000
PER = 15.79
print(시가총액, type(시가총액))
print(현재가, type(현재가))
print(PER, type(PER))
# Out:
# 총평가금액 =  500000
# 298000000000000 <class 'int'>
# 5000 <class 'int'>
# 15.79 <class 'float'>

# %% [markdown]
# ## 013 문자열 출력

# %%
s = "hello"
t = "python"
print(s, t, sep='!')
print(s+'!', t) # 정답
# Out:
# hello!python
# hello! python

# %% [markdown]
# ## 014 파이썬을 이용한 값 계산

# %%
print(2 + 2 * 3)
# Out:
# 8

# %% [markdown]
# ## 015 type 함수

# %%
a = 128
print (type(a))
# Out:
# <class 'int'>

# %% [markdown]
# ## 016~019 문자열 정수 변환, 실수 변환

# %%
num_str = " 720"
num_int = int(num_str)
print(num_int+1, type(num_int))
# Out:
# 721 <class 'int'>

# %%
num_int = 100
num_str = str(num_int)
print(num_str, type(num_str))
# Out:
# 100 <class 'str'>

# %%
str = "15.79"
float_str = float(str)
print(float_str+1, type(float_str))
# Out:
# 16.79 <class 'float'>

# %%
year = "2020"
year_int = int(year)
print("최근 3년의 연도: ", year_int-2, year_int-1, year_int)
# Out:
# 최근 3년의 연도:  2018 2019 2020

# %% [markdown]
# ## 020 파이썬 계산
# #### 에이컨이 월 48,584원에 무이자 36개월의 조건으로 홈쇼핑에서 판매되고 있습니다. 총 금액은 계산한 후 이를 화면에 출력해보세요. (변수사용하기)

# %%
monthly_payment = 48584
total_payment = monthly_payment * 36
print("총금액", total_payment, "원")
# Out:
# 총금액 1749024 원
